# %%
import numpy as np
import pandas as pd

# %%
from pandas import read_csv
path="/content/winequality-red.csv"
data=read_csv(path)

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
data.loc[(data.density<1)|(data.pH>=3)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data['fixed acidity'].describe()
# Out:
# count    1599.000000
# mean        8.319637
# std         1.741096
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
df=data.sort_values("free sulfur dioxide")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 535             9.1             0.220         0.24             2.1      0.078
# 773             7.9             0.400         0.29             1.8      0.157
# 530             9.1             0.220         0.24             2.1      0.078
# 774             7.9             0.400         0.30             1.8      0.157
# 1277            7.0             0.690         0.00             1.9      0.114
# ...             ...               ...          ...             ...        ...
# 1131            5.9             0.190         0.21             1.7      0.045
# 1558            6.9             0.630         0.33             6.7      0.235
# 396             6.6             0.735         0.02             7.9      0.122
# 400             6.6             0.735         0.02             7.9      0.122
# 1244            5.9             0.290         0.25            13.4      0.067
#
# ...

# %%
data['quality']=data['quality'].replace(5,10)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              10.0             10.00        10.00            10.0     10.000
# 1              10.0             10.00        10.00            10.0     10.000
# 2              10.0             10.00        10.00            10.0     10.000
# 3              11.2              0.28         0.56             1.9      0.075
# 4              10.0             10.00        10.00            10.0     10.000
# ...             ...               ...          ...             ...        ...
# 1594           10.0             10.00        10.00            10.0     10.000
# 1595            5.9              0.55         0.10             2.2      0.062
# 1596            6.3              0.51         0.13             2.3      0.076
# 1597           10.0             10.00        10.00            10.0     10.000
# 1598            6.0              0.31         0.47             3.6      0.067
#
# ...

# %%
df=data.rename(columns={'free sulfur dioxide': 'FSD','total sulfur dioxide':'TSD'})
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              10.0             10.00        10.00            10.0     10.000
# 1              10.0             10.00        10.00            10.0     10.000
# 2              10.0             10.00        10.00            10.0     10.000
# 3              11.2              0.28         0.56             1.9      0.075
# 4              10.0             10.00        10.00            10.0     10.000
# ...             ...               ...          ...             ...        ...
# 1594           10.0             10.00        10.00            10.0     10.000
# 1595            5.9              0.55         0.10             2.2      0.062
# 1596            6.3              0.51         0.13             2.3      0.076
# 1597           10.0             10.00        10.00            10.0     10.000
# 1598            6.0              0.31         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Pandas is helpful because: <br></br>
#
# 1. It is programmer friendly and easy to understand.
# 2. It allows us to simply adapt and manage huge amount of data.
# 3. Data cleaning is very efficient.
# 4. Easy to merge huge datasets.
