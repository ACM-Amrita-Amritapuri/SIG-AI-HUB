# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\parva\\Documents\\S3 Btech\\Club\\California_Houses.csv')
display(df)
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0                452600.0         8.3252          41        880           129
# 1                358500.0         8.3014          21       7099          1106
# 2                352100.0         7.2574          52       1467           190
# 3                341300.0         5.6431          52       1274           235
# 4                342200.0         3.8462          52       1627           280
# ...                   ...            ...         ...        ...           ...
# 20635             78100.0         1.5603          25       1665           374
# 20636             77100.0         2.5568          18        697           150
# 20637             92300.0         1.7000          17       2254           485
# 20638             84700.0         1.8672          18       1860           409
# 20639             89400.0         2.3886          16       2785           616
#
# ...

# %%
df.head()
# Out:
#    Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0            452600.0         8.3252          41        880           129
# 1            358500.0         8.3014          21       7099          1106
# 2            352100.0         7.2574          52       1467           190
# 3            341300.0         5.6431          52       1274           235
# 4            342200.0         3.8462          52       1627           280
#
#    Population  Households  Latitude  Longitude  Distance_to_coast  \
# 0         322         126     37.88    -122.23        9263.040773
# 1        2401        1138     37.86    -122.22       10225.733072
# 2         496         177     37.85    -122.24        8259.085109
# 3         558         219     37.85    -122.25        7768.086571
# 4         565         259     37.85    -122.25        7768.086571
#
#    Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# ...

# %%
df.tail()
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 20635             78100.0         1.5603          25       1665           374
# 20636             77100.0         2.5568          18        697           150
# 20637             92300.0         1.7000          17       2254           485
# 20638             84700.0         1.8672          18       1860           409
# 20639             89400.0         2.3886          16       2785           616
#
#        Population  Households  Latitude  Longitude  Distance_to_coast  \
# 20635         845         330     39.48    -121.09      162031.481121
# 20636         356         114     39.49    -121.21      160445.433537
# 20637        1007         433     39.43    -121.22      153754.341182
# 20638         741         349     39.43    -121.32      152005.022239
# 20639        1387         530     39.37    -121.24      146866.196892
#
#        Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# ...

# %%
sns.lineplot(data=df['Tot_Rooms'])
sns.lineplot(data=df['Tot_Bedrooms'])
# Out:
# <AxesSubplot:ylabel='Tot_Rooms'>

# %%
plt.figure(figsize=(10,6))
v=df.query('Median_Income <6').Median_Income
sns.barplot(x=df['Median_Age'], y=v)
# Out:
# <AxesSubplot:xlabel='Median_Age', ylabel='Median_Income'>

# %%
df.describe()
# Out:
#        Median_House_Value  Median_Income    Median_Age     Tot_Rooms  \
# count        20640.000000   20640.000000  20640.000000  20640.000000
# mean        206855.816909       3.870671     28.639486   2635.763081
# std         115395.615874       1.899822     12.585558   2181.615252
# min          14999.000000       0.499900      1.000000      2.000000
# 25%         119600.000000       2.563400     18.000000   1447.750000
# 50%         179700.000000       3.534800     29.000000   2127.000000
# 75%         264725.000000       4.743250     37.000000   3148.000000
# max         500001.000000      15.000100     52.000000  39320.000000
#
#        Tot_Bedrooms    Population    Households      Latitude     Longitude  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean     537.898014   1425.476744    499.539680     35.631861   -119.569704
# std      421.247906   1132.462122    382.329753      2.135952      2.003532
# ...

# %%
plt.figure(figsize=(14,7))
plt.title("Heat Map")
matrix = df.corr()
sns.heatmap(data= matrix, annot=True)
# Out:
# <AxesSubplot:title={'center':'Heat Map'}>

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(x=df['Median_Income'], y=df['Median_House_Value'], hue=df['Median_Age'])
# Out:
# <AxesSubplot:xlabel='Median_Income', ylabel='Median_House_Value'>

# %%
plt.figure(figsize=(14,7))
cond_age = df.query('30 <= Median_Age <= 40').Median_Age
sns.kdeplot(data=df, x='Distance_to_LA', hue=cond_age, shade=True)
# Out:
# <AxesSubplot:xlabel='Distance_to_LA', ylabel='Density'>

# %%
import plotly.express as pl
plt.figure(figsize=(15,10))
fig = pl.scatter(df, x='Households',y='Latitude', color="Median_Income")
fig.show()
# Out:
# <div>                            <div id="22173c07-e9a0-4fae-9579-6980c5aa8ef1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22173c07-e9a0-4fae-9579-6980c5aa8ef1")) {                    Plotly.newPlot(                        "22173c07-e9a0-4fae-9579-6980c5aa8ef1",                        [{"hovertemplate":"Households=%{x}<br>Latitude=%{y}<br>Median_Income=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[8.3252,8.3014,7.2574,5.6431,3.8462,4.0368,3.6591,3.12,2.0804,3.6912,3.2031,3.2705,3.075,2.6736,1.9167,2.125,2.775,2.1202,1.9911,2.6033,1.3578,1.7135,1.725,2.1806,2.6,2.4038,2.4597,1.808,1.6424,1.6875,1.9274,1.9615,1.7969,1.375,2.7303,1.4861,1.0972,1.4103,3.48,2.5898,2.0978,1.2852,1.025,3.9643,3.0125,2.6768,2.026,1.7348,0.9506,1.7
# ...
