# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("California_Houses.csv")

# %%
df.head()
# Out:
#    Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0            452600.0         8.3252          41        880           129
# 1            358500.0         8.3014          21       7099          1106
# 2            352100.0         7.2574          52       1467           190
# 3            341300.0         5.6431          52       1274           235
# 4            342200.0         3.8462          52       1627           280
#
#    Population  Households  Latitude  Longitude  Distance_to_coast  \
# 0         322         126     37.88    -122.23        9263.040773
# 1        2401        1138     37.86    -122.22       10225.733072
# 2         496         177     37.85    -122.24        8259.085109
# 3         558         219     37.85    -122.25        7768.086571
# 4         565         259     37.85    -122.25        7768.086571
#
#    Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# 0   556529.158342         735501.806984         67432.517001
# 1   554279.850069         733236.884360         65049.908574
# 2   554610.717069         733525.682937         64867.289833
# 3   555194.266086         734095.290744         65287.138412
# 4   555194.266086         734095.290744         65287.138412
#
#    Distance_to_SanFrancisco
# 0              21250.213767
# 1              20880.600400
# 2              18811.487450
# 3              18031.047568
# 4              18031.047568

# %% [markdown]
# Qn.1

# %%
sns.lineplot(data=df['Tot_Rooms'], label="Total Rooms")

sns.lineplot(data=df['Tot_Bedrooms'], label="Total Bedrooms")
plt.show()

# %% [markdown]
# Qn.2

# %%
sns.barplot(x=df.Median_Age, y=df.query('Median_Income<6').Median_Income)

# %% [markdown]
# Qn.3

# %%
corr=df.corr()
sns.heatmap(corr)

# %% [markdown]
# Qn.4

# %%
sns.scatterplot(x=df['Median_Income'], y=df['Median_House_Value'], hue=df['Median_Age'])

# %% [markdown]
# Qn.5

# %%
sns.kdeplot(x=df['Distance_to_LA'], hue=df.query('Median_Age<=40&Median_Age>=30').Median_Age, fill=True)

# %% [markdown]
# Qn.6

# %%
import plotly.express as px

# %%
fig = px.scatter(data_frame=df, x="Median_Age", y="Median_Income")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c6e75888-f628-4634-ab57-41beb7cd077b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6e75888-f628-4634-ab57-41beb7cd077b")) {                    Plotly.newPlot(                        "c6e75888-f628-4634-ab57-41beb7cd077b",                        [{"hovertemplate":"Median_Age=%{x}<br>Median_Income=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[41,21,52,52,52,52,52,52,42,52,52,52,52,52,52,50,52,52,50,52,40,42,52,52,52,41,49,52,50,52,49,52,48,49,51,49,48,52,52,52,52,51,49,52,52,52,50,43,40,40,21,43,41,52,52,52,52,52,52,2,52,49,50,52,48,52,48,52,52,46,26,46,49,46,20,17,36,19,23,38,17,52,52,52,35,52,40,10,10,52,16,52,52,27,39,36,31,29,22,37,29,28,39,52,34,52,52,52,52,28,52,32,26,52,35,52,28,52,50,47,41,37,52,52,52,28,50,44,40,30,34,18,35,34,28,26,29,32,37,39,30,52,45,50,38,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,46,42,43,41,29,27,45,50,52,36,43,52,52,52,47,52,52,49,52,51,50,52,43,52,30,39,47,52,43,51,39,52,20,52,52,52,52,52,50,43,52,44,48,49,37,30,40,44,52,52,46,49,38,29,47,34,35,39,39,43,52,52,41,48,48,46,50,40,46,52,45,28,35,49,44,45,45,46,52,52,49,44,43,47,40,50,44,51,52,52,52,49,46,43,42,39,41,52,39,50,43,44,52,52,52,52,52,33,49,52,45,39,41,46,47,50,37,34,23,24,22,42,30,43,50,49,52,47,48,45,39,39,31,41,47,37,38,50,52,49,27,42,43,49,52