# %%
import pandas as pd

# %%
wine_ds = pd.read_csv('/content/winequality-red.csv')

# %%
# first 20 rows of the dataset
wine_ds.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
# Display all data that either have "density" lesser than 1 or "pH" greater than 3.
wine_ds[(wine_ds['density'] < 1) | (wine_ds['pH'] > 3)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_ds['fixed acidity'].describe()
# Out:
# count    1599.000000
# mean        8.319637
# std         1.741096
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
wine_ds.sort_values('free sulfur dioxide' ,ascending= False)[['free sulfur dioxide']]
# Out:
#       free sulfur dioxide
# 1244                 72.0
# 396                  68.0
# 400                  68.0
# 1558                 66.0
# 1131                 57.0
# ...                   ...
# 1076                  3.0
# 774                   2.0
# 773                   1.0
# 530                   1.0
# 535                   1.0
#
# [1599 rows x 1 columns]

# %%
wine_ds['quality'].replace(5, 10)
# Out:
# 0       10
# 1       10
# 2       10
# 3        6
# 4       10
#         ..
# 1594    10
# 1595     6
# 1596     6
# 1597    10
# 1598     6
# Name: quality, Length: 1599, dtype: int64

# %%
wine_ds.rename(columns={'free sulfur dioxide': 'FSD', 'total sulfur dioxide': 'TSD'})
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# pandas are really great in machine learning because we could easily analyse the dataset without the time consuming human calculations and moreover manipulation of the dataset is easily possible, for example we could find the null values in thne dataset which we get and fix them otherwise the working of the model would be interepted.
