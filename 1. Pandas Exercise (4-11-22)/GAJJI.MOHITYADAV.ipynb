# %% [markdown]
# # Question 1

# %%
import pandas as pd 
import numpy as np

wines = pd.read_csv("D:\\Sem3\\Ai-club\\4-11-2022\\archive\\winequality-red.csv")
wines.head(20)
# Out:
#     fixed_acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %% [markdown]
# # Question 2

# %%
wines.loc[(wines.density<1)|(wines.pH>3)]
# Out:
#       fixed_acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # Question 3

# %%
wines.fixed_acidity.describe()
# Out:
# count    1599.000000
# mean        8.319637
# std         1.741096
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed_acidity, dtype: float64

# %% [markdown]
# # Question 4

# %%
free_sulfurdioxide = wines.groupby('free_sulfur_dioxide').free_sulfur_dioxide.max()
print(free_sulfurdioxide)
# Out:
# free_sulfur_dioxide
# 1.0      1.0
# 2.0      2.0
# 3.0      3.0
# 4.0      4.0
# 5.0      5.0
# 5.5      5.5
# 6.0      6.0
# 7.0      7.0
# 8.0      8.0
# 9.0      9.0
# 10.0    10.0
# 11.0    11.0
# 12.0    12.0
# 13.0    13.0
# 14.0    14.0
# 15.0    15.0
# 16.0    16.0
# 17.0    17.0
# 18.0    18.0
# 19.0    19.0
# 20.0    20.0
# 21.0    21.0
# 22.0    22.0
# 23.0    23.0
# 24.0    24.0
# 25.0    25.0
# 26.0    26.0
# 27.0    27.0
# 28.0    28.0
# 29.0    29.0
# 30.0    30.0
# 31.0    31.0
# 32.0    32.0
# 33.0    33.0
# 34.0    34.0
# 35.0    35.0
# 36.0    36.0
# 37.0    37.0
# 37.5    37.5
# 38.0    38.0
# 39.0    39.0
# 40.0    40.0
# 40.5    40.5
# 41.0    41.0
# 42.0    42.0
# 43.0    43.0
# 45.0    45.0
# 46.0    46.0
# 47.0    47.0
# 48.0    48.0
# 50.0    50.0
# 51.0    51.0
# 52.0    52.0
# 53.0    53.0
# 54.0    54.0
# 55.0    55.0
# 57.0    57.0
# 66.0    66.0
# 68.0    68.0
# 72.0    72.0
# Name: free_sulfur_dioxide, dtype: float64

# %% [markdown]
# # Question 5

# %%
wines.quality.replace(5,10)
# Out:
# 0       10
# 1       10
# 2       10
# 3        6
# 4       10
#         ..
# 1594    10
# 1595     6
# 1596     6
# 1597    10
# 1598     6
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# # Question 6

# %%
wines.rename(columns={'free_sulfur_dioxide':'FSD','total_sulfur_dioxide':'TSD'})
# Out:
#       fixed_acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # Question 7

# %% [markdown]
# Pandas is one of the tools in Machine Learning which is used for data cleaning and analysis. It has features which are used for exploring, cleaning, transforming and visualizing from data.
