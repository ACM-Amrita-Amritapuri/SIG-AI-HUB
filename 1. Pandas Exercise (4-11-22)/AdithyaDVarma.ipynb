# %% [markdown]
# # TASK-1

# %%
import pandas as pd
data=pd.read_csv('winequality-red.csv')
print(data.head(20))
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %% [markdown]
# # TASK-2

# %%
data.loc[(data.density < 1) | (data.pH > 3)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # TASK-3

# %%
import pandas as pd

data['fixed acidity'].describe()
# Out:
# count    1599.000000
# mean        8.319637
# std         1.741096
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %% [markdown]
# # TASK-4

# %%
data.sort_values(by='free sulfur dioxide')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 535             9.1             0.220         0.24             2.1      0.078
# 773             7.9             0.400         0.29             1.8      0.157
# 530             9.1             0.220         0.24             2.1      0.078
# 774             7.9             0.400         0.30             1.8      0.157
# 1277            7.0             0.690         0.00             1.9      0.114
# ...             ...               ...          ...             ...        ...
# 1131            5.9             0.190         0.21             1.7      0.045
# 1558            6.9             0.630         0.33             6.7      0.235
# 396             6.6             0.735         0.02             7.9      0.122
# 400             6.6             0.735         0.02             7.9      0.122
# 1244            5.9             0.290         0.25            13.4      0.067
#
# ...

# %% [markdown]
# # TASK-5

# %%
data.quality.replace(5,10)
# Out:
# 0       10
# 1       10
# 2       10
# 3        6
# 4       10
#         ..
# 1594    10
# 1595     6
# 1596     6
# 1597    10
# 1598     6
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# # TASK-6

# %%
data.rename(columns={'free sulfur dioxide': 'FSD','total sulfur dioxide': 'TSD'},inplace = True)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # TASK-7

# %% [markdown]
# Pandas is a really good library which can be used for data manipulation and data visuzlization.
#
# Pandas provide a really good and detailed data representation.
# Pandas has a really good set of commands and features where it can be used for analyzing data easier.
# Pandas can handle large det of data.
# Pandas enables us to edit, and customize the data set according to our use.
