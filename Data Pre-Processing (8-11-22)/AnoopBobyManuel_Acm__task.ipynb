# %%
from pandas import read_csv
data = read_csv('/Data_Set.csv')
import pandas as pd

# %%
print(data.head(10))
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6      01/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7      01/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8      01/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9      01/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10      01/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# ...

# %%
data.isna().sum()
df = data.dropna(axis = 1)

# %%
df.describe()
# Out:
#                 SNo      Confirmed        Deaths     Recovered
# count  10671.000000   10671.000000  10671.000000  10671.000000
# mean    5336.000000     993.821666     40.667229    289.508481
# std     3080.596695    6268.835379    398.618024   3010.809184
# min        1.000000       0.000000      0.000000      0.000000
# 25%     2668.500000       3.000000      0.000000      0.000000
# 50%     5336.000000      31.000000      0.000000      0.000000
# 75%     8003.500000     229.000000      2.000000     14.000000
# max    10671.000000  105792.000000  12428.000000  63153.000000

# %%
df = pd.DataFrame(df)

# %%
no_features = len(df.axes[1])
no_features
# Out:
# 7

# %% [markdown]
# # Data enhancement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10671 entries, 0 to 10670
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNo              10671 non-null  int64
#  1   ObservationDate  10671 non-null  object
#  2   Country/Region   10671 non-null  object
#  3   Last Update      10671 non-null  object
#  4   Confirmed        10671 non-null  float64
#  5   Deaths           10671 non-null  float64
#  6   Recovered        10671 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 583.7+ KB

# %%
from sklearn import preprocessing
  
label_encoder = preprocessing.LabelEncoder()
  

df['ObservationDate']= label_encoder.fit_transform(df['ObservationDate'])
  



df['Country/Region']= label_encoder.fit_transform(df['Country/Region'])
  

df['Last Update']= label_encoder.fit_transform(df['Last Update'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10671 entries, 0 to 10670
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNo              10671 non-null  int64
#  1   ObservationDate  10671 non-null  int64
#  2   Country/Region   10671 non-null  int64
#  3   Last Update      10671 non-null  int64
#  4   Confirmed        10671 non-null  float64
#  5   Deaths           10671 non-null  float64
#  6   Recovered        10671 non-null  float64
# dtypes: float64(3), int64(4)
# memory usage: 583.7 KB

# %%
df.describe()
# Out:
#                 SNo  ObservationDate  Country/Region   Last Update  \
# count  10671.000000     10671.000000    10671.000000  10671.000000
# mean    5336.000000        46.817543      126.291350   1184.258270
# std     3080.596695        17.674161       62.908409    619.354947
# min        1.000000         0.000000        0.000000      0.000000
# 25%     2668.500000        37.000000       80.000000    691.500000
# 50%     5336.000000        51.000000      122.000000   1365.000000
# 75%     8003.500000        61.000000      197.000000   1805.000000
# max    10671.000000        69.000000      214.000000   1813.000000
#
#            Confirmed        Deaths     Recovered
# count   10671.000000  10671.000000  10671.000000
# mean      993.821666     40.667229    289.508481
# std      6268.835379    398.618024   3010.809184
# min         0.000000      0.000000      0.000000
# 25%         3.000000      0.000000      0.000000
# 50%        31.000000      0.000000      0.000000
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,fmt=".0%")

# %%
sns.pairplot(df.iloc[:,1:5])

# %%
plt.scatter(df['Confirmed'] , df['Deaths'],c='red')
plt.figure(figsize=(15,15))
plt.show()

# %% [markdown]
# The model will be a good fit since the scatter plot is almost the same
